# %%
import pandas as pd
import numpy as np 
import psycopg2
from sqlalchemy import create_engine
import os
import pymongo
from bson.json_util import loads, dumps

# %%
postgres_password = os.environ['POSTGRES_PASSWORD']
mongo_username = os.environ['MONGO_INITDB_ROOT_USERNAME']
mongo_password = os.environ['MONGO_INITDB_ROOT_PASSWORD']
mongo_init_db = os.environ['MONGO_INITDB_DATABASE']

# %%
engine = create_engine('postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}'.format(
    user = 'postgres',
    password = postgres_password,
    host = 'postgres',
    port = '5432',
    db = 'contrans'))

# %%
charwords = pd.read_csv('charwords.csv')

# %%
charwords.columns
# Out:
# Index(['Unnamed: 0', 'word', 'tf_idf', 'sponsor_id'], dtype='object')

# %%
charwords = charwords.drop(['Unnamed: 0'], axis=1)

# %%
charwords.to_sql('charwords', con=engine, chunksize=1000, index=False, if_exists='replace')
# Out:
# 5500

# %%
myquery = '''
SELECT c.word, c.tf_idf
FROM charwords c
INNER JOIN members m
    ON c.sponsor_id = m.propublica_id
WHERE m.last_name like '%%GAETZ'

'''
pd.read_sql_query(myquery, con=engine)
# Out:
#                     word    tf_idf
# 0              jerusalem  0.124535
# 1  digital health passes  0.104751
# 2          health passes  0.104751
# 3         digital health  0.100667
# 4             city david  0.093112
# 5               escambia  0.088801
# 6           hunter biden  0.084453
# 7               lionfish  0.081473
# 8                   tags  0.080029
# 9        escambia county  0.077701

# %%
myquery = '''
SELECT * 
FROM members
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#                   title short_title first_name middle_name   last_name suffix  \
# 0        Representative        Rep.       Alma        None       ADAMS   None
# 1        Representative        Rep.     Robert          B.    ADERHOLT   None
# 2        Representative        Rep.       Pete        None     AGUILAR   None
# 3        Representative        Rep.       Rick        None       ALLEN   None
# 4        Representative        Rep.      Colin        None      ALLRED   None
# ..                  ...         ...        ...         ...         ...    ...
# 552  Senator, 1st Class        Sen.  Elizabeth        None      WARREN   None
# 553  Senator, 1st Class        Sen.    Sheldon        None  WHITEHOUSE   None
# 554  Senator, 1st Class        Sen.      Roger        None      WICKER   None
# 555  Senator, 3rd Class        Sen.        Ron        None       WYDEN   None
# 556  Senator, 3rd Class        Sen.       Todd        None       YOUNG   None
#
#      congress chamber    icpsr state  ...                              office  \
# 0       117.0   House  21545.0    NC  ...  2436 Rayburn House Office Building
# 1       117.0   House  29701.0    AL  ...    266 Cannon House Office Building
# 2       117.0   House  21506.0    CA  ...    109 Cannon House Office Building
# 3       117.0   House  21516.0    GA  ...    570 Cannon House Office Building
# 4       117.0   House  21900.0    TX  ...    114 Cannon House Office Building
# ..        ...     ...      ...   ...  ...                                 ...
# 552     117.0  Senate  41301.0    MA  ...     309 Hart Senate Office Building
# 553     117.0  Senate  40704.0    RI  ...     530 Hart Senate Office Building
# 554     117.0  Senate  29534.0    MS  ...  555 Dirksen Senate Office Building
# 555     117.0  Senate  14871.0    OR  ...  221 Dirksen Senate Office Building
# 556     117.0  Senate  21133.0    IN  ...  185 Dirksen Senate Office Building
#
#             phone           fax missed_votes_pct votes_with_party_pct  \
# 0    202-225-1510          None             0.32                99.04
# 1    202-225-4876          None             1.49                96.30
# 2    202-225-3201          None             0.32                98.82
# 3    202-225-2823          None             2.98                91.05
# 4    202-225-2231          None             1.06                98.17
# ..            ...           ...              ...                  ...
# 552  202-224-4543          None             0.67                97.85
# 553  202-224-2921          None             1.35                99.32
# 554  202-224-6253          None             1.46                89.86
# 555  202-224-5244  202-228-2717             1.01                99.09
# 556  202-224-5623  202-226-6866             2.70                86.75
#
#     votes_against_party_pct DWNOMINATE propublica_id  \
# 0                      0.86     -0.465       A000370
# 1                      3.59      0.380       A000055
# 2                      1.07     -0.296       A000371
# 3                      8.84      0.699       A000372
# 4                      1.73     -0.432       A000376
# ..                      ...        ...           ...
# 552                    2.15     -0.753       W000817
# 553                    0.68     -0.354       W000802
# 554                   10.14      0.377       W000437
# 555                    0.91     -0.330       W000779
# 556                   13.25      0.458       Y000064
#
#                                    propublica_endpoint  \
# 0    https://api.propublica.org/congress/v1/members...
# 1    https://api.propublica.org/congress/v1/members...
# 2    https://api.propublica.org/congress/v1/members...
# 3    https://api.propublica.org/congress/v1/members...
# 4    https://api.propublica.org/congress/v1/members...
# ..                                                 ...
# 552  https://api.propublica.org/congress/v1/members...
# 553  https://api.propublica.org/congress/v1/members...
# 554  https://api.propublica.org/congress/v1/members...
# 555  https://api.propublica.org/congress/v1/members...
# 556  https://api.propublica.org/congress/v1/members...
#
#                   last_updated
# 0    2022-12-01 09:30:11 -0500
# 1    2022-12-01 09:30:10 -0500
# 2    2022-12-01 09:30:11 -0500
# 3    2022-12-01 09:30:10 -0500
# 4    2022-12-01 09:30:11 -0500
# ..                         ...
# 552  2022-12-01 06:49:17 -0500
# 553  2022-12-01 06:49:16 -0500
# 554  2022-12-01 06:49:16 -0500
# 555  2022-12-01 06:49:16 -0500
# 556  2022-11-29 16:17:11 -0500
#
# [557 rows x 36 columns]

# %%
myclient = pymongo.MongoClient(f"mongodb://{mongo_username}:{mongo_password}@mongo:27017/{mongo_init_db}?authSource=admin")

# %%
contrans_db = myclient['contrans']
bills = contrans_db['bills']

# %%
#bills.insert_many
bills.count_documents({})
# Out:
# 17071

# %%
bills.find_one({})
# Out:
# {'_id': ObjectId('63764e009bcb2a47fa57a599'),
#  'bill_id': 'sres835-117',
#  'bill_slug': 'sres835',
#  'bill_type': 'sres',
#  'number': 'S.RES.835',
#  'bill_uri': 'https://api.propublica.org/congress/v1/117/bills/sres835.json',
#  'title': 'A resolution expressing support for the designation of October 2022 as "National Youth Justice Action Month".',
#  'short_title': 'A resolution expressing support for the designation of October 2022 as "National Youth Justice Action Month".',
#  'sponsor_title': 'Sen.',
#  'sponsor_id': 'W000802',
#  'sponsor_name': 'Sheldon Whitehouse',
#  'sponsor_state': 'RI',
#  'sponsor_party': 'D',
#  'sponsor_uri': 'https://api.propublica.org/congress/v1/members/W000802.json',
#  'gpo_pdf_uri': None,
#  'congressdotgov_url': 'https://www.congress.gov/bill/117th-congress/senate-resolution/835',
#  'govtrack_url': 'https://www.govtrack.us/congress/bills/117/sres835',
#  'introduced_date': '2022-11-16',
#  'active': False,
#  'last_vote': None,
#  'house_passage': None,
#  'senate_passage': None,
#  'enacted': None,
#  'vetoed': None,
#  'cosponsors': 1,
#  'cosponsors_by_party': {'D': 1},
#  'committees': 'Senate Judiciary Committee',
#  'committee_codes': ['SSJU'],
#  'subcommittee_codes': [],
#  'primary_subject': '',
#  'summary': '',
#  'summary_short': '',
#  'latest_major_action_date': '2022-11-16',
#  'latest_major_action': 'Referred to the Committee on the Judiciary.'}

# %%
myquery = bills.find({'introduced_date': '2022-11-16'}, 
           {'_id': 0, 'short_title':1, 'sponsor_name':1, 'introduced_date':1}) #rows then columns

# %%
loads(dumps(myquery))
# Out:
# [{'short_title': 'A resolution expressing support for the designation of October 2022 as "National Youth Justice Action Month".',
#   'sponsor_name': 'Sheldon Whitehouse',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A resolution permitting the collection of clothing, toys, food, and housewares during the holiday season for charitable purposes in Senate buildings.',
#   'sponsor_name': 'Jon Tester',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to amend the Truth in Lending Act to address certain issues relating to the extension of consumer credit, and for other purposes.',
#   'sponsor_name': 'Jeff Merkley',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to authorize the Secretary of the Interior to issue a right-of-way permit with respect to a natural gas distribution main within Valley Forge National Historical Park, and for other purposes.',
#   'sponsor_name': 'Bob Casey',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to amend the Omnibus Crime Control and Safe Streets Act of 1968 to authorize law enforcement agencies to use COPS grants for recruitment activities, and for other purposes.',
#   'sponsor_name': 'Deb Fischer',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to amend the Internal Revenue Code of 1986 to qualify homeless youth and veterans who are full-time students for purposes of the low income housing tax credit.',
#   'sponsor_name': 'Rob Portman',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to make a technical amendment to the Violence Against Women Act of 1994, and for other purposes',
#   'sponsor_name': 'Mazie K. Hirono',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to require the Secretary of the Treasury to mint coins in commemoration of the 250th Anniversary of the United States Marine Corps, and to support programs at the Marine Corps Heritage Center.',
#   'sponsor_name': 'Richard Blumenthal',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to strengthen the collection of data regarding interactions between law enforcement officers and individuals with disabilities.',
#   'sponsor_name': 'Bob Casey',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to amend the Homeland Security Act of 2002 to provide training for Department of Homeland Security personnel regarding the use of containment devices to prevent exposure to potential synthetic opioids, and for other purposes.',
#   'sponsor_name': 'Sherrod Brown',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to require Transmission Organizations to accept bids from aggregators of certain retail customers, and for other purposes.',
#   'sponsor_name': 'Richard J. Durbin',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to amend the Elementary and Secondary Education Act of 1965 to require the National Advisory Council on Indian Education to include at least 1 member who is the president of a Tribal College or University and to require the Secretaries of Education',
#   'sponsor_name': 'Deb Fischer',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to modify the Intercountry Adoption Act of 2000 to provide a specialized accreditation option for performing a background study on a child or a home study on prospective adoptive parents, and reporting on such a study.',
#   'sponsor_name': 'Roger Wicker',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to establish and implement a multi-year Legal Gold and Mining Partnership Strategy to reduce the negative environmental and social impacts of illicit gold mining in the Western Hemisphere, and for other purposes.',
#   'sponsor_name': 'Marco Rubio',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to authorize the Community Advantage Loan Program of the Small Business Administration, and for other purposes.',
#   'sponsor_name': 'Benjamin L. Cardin',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to direct the Secretary of Education to develop and disseminate an evidence-based curriculum for kindergarten through grade 12 on substance use disorders.',
#   'sponsor_name': 'Joe Manchin III',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to amend title XVIII of the Social Security Act to ensure Medicare-only PACE program enrollees have a choice of prescription drug plans under Medicare part D.',
#   'sponsor_name': 'Thomas R. Carper',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'A bill to provide accountability for funding provided to the Internal Revenue Service and the Department of Treasury under Public Law 117-169.',
#   'sponsor_name': 'John Thune',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To authorize the extension of nondiscriminatory treatment (normal trade relations treatment) to the products of Kazakhstan, Uzbekistan, and Tajikistan.',
#   'sponsor_name': 'Thomas Suozzi',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Animal Welfare Act to provide for greater protection of roosters, and for other purposes.',
#   'sponsor_name': 'Cynthia Axne',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Internal Revenue Code of 1986 to qualify homeless youth and veterans who are full-time students for purposes of the low-income housing tax credit.',
#   'sponsor_name': 'Danny K. Davis',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To direct the Librarian of Congress to obtain a stained glass panel depicting the seal of the District of Columbia and install the panel among the stained glass panels depicting the seals of States, which overlook the Main Reading Room of the Library of C',
#   'sponsor_name': 'Eleanor Holmes Norton',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Public Health Service Act to provide for the development and publication of independent value assessments for drugs, and for other purposes.',
#   'sponsor_name': 'Jackie Speier',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Securities Act of 1933 to require the accounting principles standard setting body to comply with the Administrative Procedure Act and the Government in the Sunshine Act, to require the head of such body to testify annually before Congress, an',
#   'sponsor_name': 'Blaine Luetkemeyer',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Internal Revenue Code of 1986 to allow a refundable credit against income tax for tuition expenses incurred for each qualifying child of the taxpayer in attending public or private elementary or secondary school.',
#   'sponsor_name': 'Christopher H. Smith',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Truth in Lending Act to address certain issues relating to the extension of consumer credit, and for other purposes.',
#   'sponsor_name': 'Suzanne Bonamici',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To prohibit the provision of Federal funds to a labor organization the members of which are education professionals.',
#   'sponsor_name': 'Ronny Jackson',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Public Health Service Act to give the United States Preventive Services Task Force the authority to take early action based on scientific evidence, and for other purposes.',
#   'sponsor_name': 'Lisa Blunt Rochester',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Food and Nutrition Act of 2008 to provide for the reissuance to households supplemental nutrition assistance program benefits to replace benefits stolen by identity theft or typical skimming practices, and for other purposes.',
#   'sponsor_name': 'C.A. Dutch Ruppersberger',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To authorize the use of FBI criminal history record information for administration of interstate compacts, and for other purposes.',
#   'sponsor_name': 'Tracey Mann',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To designate the facility of the United States Postal Service located at 6401 El Cajon Boulevard in San Diego, California, as the "Susan A. Davis Post Office".',
#   'sponsor_name': 'Sara Jacobs',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To establish a task force on child and family economic security and stability for economic growth.',
#   'sponsor_name': 'Nydia M. Velázquez',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To provide for advancements in carbon removal research, quantification, and commercialization, including by harnessing natural processes, and for other purposes.',
#   'sponsor_name': 'Scott Peters',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To authorize the Community Advantage Loan Program of the Small Business Administration, and for other purposes.',
#   'sponsor_name': 'Judy Chu',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To provide enhanced capabilities to combat transnational criminal cartels, and for other purposes.',
#   'sponsor_name': 'Dan Crenshaw',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To require the Secretary of the Treasury to mint coins in commemoration of the 250th Anniversary of the United States Marine Corps, and to support programs at the Marine Corps Heritage Center.',
#   'sponsor_name': 'Seth Moulton',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'To amend the Worker Adjustment and Retraining Notification Act to require employers who are ordering a plant closing or mass layoff to cover the cost of an economic impact study in each impacted unit of local government, and for other purposes.',
#   'sponsor_name': 'Mark DeSaulnier',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Calling for the submission to the House of Representatives of certain information in the possession of the Attorney General regarding NICS Indices Self-Submission Forms.',
#   'sponsor_name': 'Andrew Clyde',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Of inquiry requesting the President to provide to the House of Representatives certain documents or records relating to coordination between social media companies and the Biden administration on information, censorship, and censorship meetings in order t',
#   'sponsor_name': 'Andrew Clyde',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Of inquiry requesting the President and directing the Secretary of Defense to transmit to the House of Representatives any record created on or after January 21, 2021, under the control of the President or the Secretary, respectively, that refers to the D',
#   'sponsor_name': 'Andrew Clyde',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Calling for the submission to the House of Representatives of certain information regarding the decision of the President of the United States to institute the "Ghost Gun" Rule.',
#   'sponsor_name': 'Andrew Clyde',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Promoting stronger economic relations between the United States and countries in Latin America and the Caribbean.',
#   'sponsor_name': 'Albio Sires',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Expressing support for the designation of November 16, 2022, as "National GIS Day".',
#   'sponsor_name': 'John Curtis',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Recognizing the 75th anniversary of Everglades National Park.',
#   'sponsor_name': 'Sheila Cherfilus-McCormick',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Urging United States policy toward Guatemala to support the rule of law and address challenges of kleptocracy, organized crime, private and public sector corruption, illicit campaign financing, criminalization of and attacks on justice operators, journali',
#   'sponsor_name': 'Norma Torres',
#   'introduced_date': '2022-11-16'},
#  {'short_title': 'Of inquiry requesting the President transmit certain documents in his possession to the House of Representatives relating to the surveillance or monitoring of pro-gun, pro-life, or conservative groups under the Internet Covert Operations Program operated ',
#   'sponsor_name': 'Andrew Clyde',
#   'introduced_date': '2022-11-16'}]

# %%
pd.DataFrame.from_records(loads(dumps(myquery)))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
myquery = bills.find({'enacted': {'$ne': None}}, 
           {'_id': 0, 'enacted':1, 'short_title':1, 'sponsor_name':1})

# %%
laws = pd.DataFrame.from_records(loads(dumps(myquery)))

# %%
laws['sponsor_name'].value_counts()
# Out:
# Gary Peters          10
# John Cornyn           8
# Amy Klobuchar         6
# Rosa DeLauro          6
# Jon Tester            5
#                      ..
# Cynthia M. Lummis     1
# John Boozman          1
# Jason Crow            1
# Don Bacon             1
# Bobby L. Rush         1
# Name: sponsor_name, Length: 140, dtype: int64

# %%
myquery = '''
SELECT c.word, c.tf_idf
FROM charwords c
INNER JOIN members m
    ON c.sponsor_id = m.propublica_id
WHERE m.first_name LIKE '%%Gary' AND m.last_name like '%%PETERS'

'''
pd.read_sql_query(myquery, con=engine)
# Out:
#                                     word    tf_idf
# 0                          cybersecurity  0.185600
# 1                                fedramp  0.159005
# 2         infrastructure security agency  0.150585
# 3  cybersecurity infrastructure security  0.150385
# 4           cybersecurity infrastructure  0.149688
# 5                infrastructure security  0.144829
# 6                 director cybersecurity  0.142051
# 7  director cybersecurity infrastructure  0.141411
# 8                        security agency  0.134354
# 9                               incident  0.128406

# %%
bills.drop_index([('bill_text', 'text')])
bills.create_index([('short_title', 'text')])
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 bills.drop_index([('bill_text', 'text')])
#       2 bills.create_index([('short_title', 'text')])
#
# File /usr/local/lib/python3.11/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/pymongo/collection.py:2148, in Collection.drop_index(self, index_or_name, session, comment, **kwargs)
#    2146     cmd["comment"] = comment
#    2147 with self._socket_for_writes(session) as sock_info:
# -> 2148     self._command(
#    2149         sock_info,
#    2150         cmd,
#    2151         read_preference=ReadPreference.PRIMARY,
#    2152         allowable_errors=["ns not found", 26],
#    2153         write_concern=self._write_concern_for(session),
#    2154         session=session,
#    2155     )
#
# File /usr/local/lib/python3.11/site-packages/pymongo/collection.py:285, in Collection._command(self, sock_info, command, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     258 """Internal command helper.
#     259
#     260 :Parameters:
#    (...)
#     282   The result document.
#     283 """
#     284 with self.__database.client._tmp_session(session) as s:
# --> 285     return sock_info.command(
#     286         self.__database.name,
#     287         command,
#     288         read_preference or self._read_preference_for(session),
#     289         codec_options or self.codec_options,
#     290         check,
#     291         allowable_errors,
#     292         read_concern=read_concern,
#     293         write_concern=write_concern,
#     294         parse_write_concern_error=True,
#     295         collation=collation,
#     296         session=s,
#     297         client=self.__database.client,
#     298         retryable_write=retryable_write,
#     299         user_fields=user_fields,
#     300     )
#
# File /usr/local/lib/python3.11/site-packages/pymongo/pool.py:767, in SocketInfo.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     765     self._raise_if_not_writable(unacknowledged)
#     766 try:
# --> 767     return command(
#     768         self,
#     769         dbname,
#     770         spec,
#     771         self.is_mongos,
#     772         read_preference,
#     773         codec_options,
#     774         session,
#     775         client,
#     776         check,
#     777         allowable_errors,
#     778         self.address,
#     779         listeners,
#     780         self.max_bson_size,
#     781         read_concern,
#     782         parse_write_concern_error=parse_write_concern_error,
#     783         collation=collation,
#     784         compression_ctx=self.compression_context,
#     785         use_op_msg=self.op_msg_enabled,
#     786         unacknowledged=unacknowledged,
#     787         user_fields=user_fields,
#     788         exhaust_allowed=exhaust_allowed,
#     789         write_concern=write_concern,
#     790     )
#     791 except (OperationFailure, NotPrimaryError):
#     792     raise
#
# File /usr/local/lib/python3.11/site-packages/pymongo/network.py:166, in command(sock_info, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     164             client._process_response(response_doc, session)
#     165         if check:
# --> 166             helpers._check_command_response(
#     167                 response_doc,
#     168                 sock_info.max_wire_version,
#     169                 allowable_errors,
#     170                 parse_write_concern_error=parse_write_concern_error,
#     171             )
#     172 except Exception as exc:
#     173     if publish:
#
# File /usr/local/lib/python3.11/site-packages/pymongo/helpers.py:181, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     178 elif code == 43:
#     179     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 181 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: index not found with name [bill_text_text], full error: {'ok': 0.0, 'errmsg': 'index not found with name [bill_text_text]', 'code': 27, 'codeName': 'IndexNotFound'}

# %%
#all the bills that had at least 5 co-sponsors and sort by most relevant to Ukraine
myquery = bills.find({'cosponsors':{'$gte':5}, '$text': {'$search': 'ukraine', '$caseSensitive': False}}, 
           {'_id': 0, 'score':{'$meta': 'textScore'}, 'short_title':1, 'sponsor_name':1, 'cosponsors':1})

# %%
relateukraine = pd.DataFrame.from_records(loads(dumps(myquery)))
relateukraine
